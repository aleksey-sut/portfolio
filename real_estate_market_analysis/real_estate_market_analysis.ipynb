# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных,-изучение-общей-информации" data-toc-modified-id="Обзор-данных,-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных, изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Приведение-данные-к-нужным-типам:" data-toc-modified-id="Приведение-данные-к-нужным-типам:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Приведение данные к нужным типам:</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров: площадь, цена, число комнат, высота потолков</a></span></li><li><span><a href="#Изучение-время-продажи-квартиры.-Построение-гистограммы.-Подсчет-средней-и-медианы.-Ответить-на-следующие-вопросы:-Сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучение-время-продажи-квартиры.-Построение-гистограммы.-Подсчет-средней-и-медианы.-Ответить-на-следующие-вопросы:-Сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение время продажи квартиры. Построение гистограммы. Подсчет средней и медианы. Ответить на следующие вопросы: Сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Убрать-редкие-и-выбивающиеся-значения.-Описать,-какие-особенности-обнаружили." data-toc-modified-id="Убрать-редкие-и-выбивающиеся-значения.-Описать,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучить-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучить-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучить-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучить-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлить-до-целых-значений.-После-этого-посчитайть-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлить-до-целых-значений.-После-этого-посчитайть-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.</a></span></li><li><span><a href="#Выделить-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделить-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделить сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель исследования:**
#
# 1. Изучение следующих параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.
#
# 2. Изучение время продажи квартиры. Построение гистограмы. Подсчет средней и медианы. Ответить на следующие вопросы: Сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#
# 3. Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.
#
# 4. Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.
#
# 5. Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.
#
# 6. Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.
#
# 7. Выделить сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# **Этапы иссслледования:**
# 1. [Обзор данных, изучение общей информации](#start)
# 2. [Предобработка данных](#preprocessing)<br>
#    2.1. [Обработка пропусков](#null)<br>
#    2.2. [Приведение данные к нужным типам:](#change)<br>
# 3. [Расчёты и добавление результатов в таблицу](#calculation)<br>
# 4. [Исследовательский анализ данных](#investigation)<br>
#    4.1. [Изучение параметров: площадь, цена, число комнат, высота потолков](#investigation_41)<br>
#    4.2. [Изучение время продажи квартиры. Построение гистограммы. Подсчет средней и медианы. Ответить на следующие вопросы: Сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?](#investigation_42)<br>
#    4.3. [Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.](#investigation_43)<br>
#    4.4. [Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.](#investigation_44)<br>
#    4.5. [Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.](#investigation_45)<br>
#    4.6. [Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.](#investigation_46)<br>
#    4.7. [Выделить сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?](#investigation_47)<br>
# 5. [Общий вывод](#conclusion)<br>

# %% [markdown]
# <a id ="start"></a>
# ## Обзор данных, изучение общей информации

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
#  **Описание столбцов таблицы**
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %%
df = df.rename(columns={'cityCenters_nearest':'city_сenters_nearest', 'parks_around3000': 'parks_around_3000', 'ponds_around3000': 'ponds_around_3000'})

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_сenters_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ### Вывод

# %% [markdown]
# В предоставленном файле 23699 наблюдений - колличество достаточное для проведения исследования.<br>
#
# В столбцах 'ceiling_height', 'floors_total', 'living_area','kitchen_area', 'balcony','locality_name', 'airports_nearest', 'city_сenters_nearest','parks_around_3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition' - есть пропуски значений в данных.
#
# В некоторых столбцах необходимо изменить тип данных.

# %% [markdown]
# <a id ="preprocessing"></a>
# ## Предобработка данных

# %% [markdown]
# <a id ="null"></a>
# ### Обработка пропусков

# %% [markdown]
# Доля пропусков в столбцах:

# %%
df.isna().mean()
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.387991
# floors_total            0.003629
# living_area             0.080299
# floor                   0.000000
# is_apartment            0.882906
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.096122
# balcony                 0.486054
# locality_name           0.002068
# airports_nearest        0.233850
# city_сenters_nearest    0.232879
# parks_around_3000       0.232837
# parks_nearest           0.659100
# ponds_around_3000       0.232837
# ponds_nearest           0.615596
# days_exposition         0.134225
# dtype: float64

# %% [markdown]
# **Необходимые действия:**
#
# Доля пропусков в столбцах, информация из которых не используется для ответов на вопросы исследования:
#
# - is_apartment: 88% - заменим пропуски на False
# - balcony: 49% - заменим пропуски на 0
# - parks_around_3000: 23% - оставим пропуски без замены
# - parks_nearest: 66% - оставим пропуски без замены
# - ponds_around_3000 - оставим пропуски без замены
# - ponds_nearest: 62% - оставим пропуски без замены
#
# - airports_nearest: 23% - заменим средними значениями, сгруппировав по столбцу locality_name
#
# Доля пропусков в столбцах, информация из которых напрямую используется для ответов на вопросы исследования и необходима замена:
#
# - ceiling_height: 39% - заменим средними значениями, сгруппировав по столбцу locality_name
# - floors_total: 0,4% - заменим средними значениями, сгруппировав по столбцу locality_name
# - city_сenters_nearest: 23% - заменим средними значениями, сгруппировав по столбцу locality_name
# - living_area: 8% - заменим средними значениями, сгруппировав по столбцу total_area
# - kitchen_area: 9,6% - заменим средними значениями, сгруппировав по столбцу total_area

# %% [markdown]
# Выведем коэффциенты корреляции между столбцами для определения взаимосвязи между ними

# %%
df.corr()
# Out:
#                       total_images  last_price  total_area     rooms  \
# total_images              1.000000    0.104473    0.115352  0.099288
# last_price                0.104473    1.000000    0.653675  0.363343
# total_area                0.115352    0.653675    1.000000  0.758344
# rooms                     0.099288    0.363343    0.758344  1.000000
# ceiling_height           -0.001987    0.085430    0.095490  0.054457
# floors_total              0.010427   -0.006984   -0.075774 -0.228215
# living_area               0.104780    0.566492    0.939537  0.845977
# floor                     0.031340    0.026576   -0.024754 -0.150862
# studio                   -0.029303   -0.025362   -0.072653 -0.147286
# open_plan                -0.024407   -0.008802   -0.034885 -0.087500
# kitchen_area              0.104756    0.519869    0.609121  0.269945
# balcony                   0.121693    0.029646    0.047937  0.017991
# airports_nearest         -0.002298   -0.026239   -0.030753 -0.061199
# ...

# %%
fig, ax = plt.subplots()
sns.heatmap(df.corr())
ax.set_title('Матрица корреляции')
fig.set_figwidth(10)
fig.set_figheight(10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Замена ропусков в столбце 'balcony'**
#
# Заменим пропуски в столбце 'balcony'. если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0

# %%
df['balcony'] = df['balcony'].fillna(0)

# %%
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Замена ропусков в столбце 'is_apartment'**
#
# Заменим пропуски в столбце 'is_apartment' на False,  так как если не указано что аппартаменты, скорее всего это не аппартаменты.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %%
df['is_apartment'].isna().sum()
# Out:
# 0

# %%
def change_null (df, column, grouping):
    df[column] = df[column].fillna(df.groupby(grouping)[column].transform('mean'))
    return df[column]

# %% [markdown]
# **Замена пропусков в столбце 'living_area'**
#
# Для замены нулевых значений в столбце living_aria будем использовать средние значения жилая площадь в разрезе общей площади (столбец total_area), имеющие наибольший коэффициент корреляции 0,94.

# %%
df['living_area'] = change_null (df, 'living_area', 'total_area')

# %%
df['living_area'].isna().sum()
# Out:
# 143

# %%
#df['living_area'] = df['living_area'].fillna(df.groupby('total_area')['living_area'].transform('mean'))

# %%
#df['living_area'].isna().sum()

# %% [markdown]
# После замены осталось 143 нулевых значения. Это связано с отсутствием данных по некоторым значениям living_area для определенных единичных total_area. Заменим их на средние значения living_area при группировке по столбцу rooms

# %%
df['living_area'] = change_null (df, 'living_area', 'rooms')

# %%
#df['living_area'] = df['living_area'].fillna(df.groupby('rooms')['living_area'].transform('mean'))

# %%
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Замена пропусков в столбце 'kitchen_area'**
#
# Для замены нулевых значений в столбце kitchen_aria будем использовать средние значения kitchen_area в разрезе общей площади (столбец total_area), имеющийе наибольший коэффициент корреляции 0,6.

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('total_area')['kitchen_area'].transform('mean'))

# %%
df['kitchen_area'].isna().sum()
# Out:
# 205

# %% [markdown]
# Оставшиеся 205 пропусков - Заменим их на средние значения kitchen_area при группировке по столбцу living_area

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('living_area')['kitchen_area'].transform('mean'))

# %%
df['kitchen_area'].isna().sum()
# Out:
# 27

# %% [markdown]
# Оставшиеся 27 пропусков - Заменим их на средние значения kitchen_area при группировке по столбцу rooms

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('rooms')['kitchen_area'].transform('mean'))

# %%
df['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Замена пропусков в столбце 'airports_nearest'**
#
# Для замены нулевых значений в столбце airports_nearest будем использовать средние значения airports_nearest в разрезе населенного пункта (locality_name).

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(df.groupby('locality_name')['airports_nearest'].transform('mean'))

# %%
df['airports_nearest'].isna().sum()
# Out:
# 5394

# %% [markdown]
# **Замена пропусков в столбце 'city_сenters_nearest'**
#
# Для замены нулевых значений в столбце city_сenters_nearest будем использовать средние значения city_сenters_nearest в разрезе населенного пункта (locality_name).

# %%
df['city_сenters_nearest'] = df['city_сenters_nearest'].fillna(df.groupby('locality_name')['city_сenters_nearest'].transform('mean'))

# %%
df['city_сenters_nearest'].isna().sum()
# Out:
# 5394

# %% [markdown]
# Вывод - в некоторых населенных пунктах не указаны расстояния до центра и до аэропорта. Логически, эти данные больше не связаны с другими колонками, ставляем х без изменения

# %% [markdown]
# **Замена пропусков в столбце 'floors_total'**
#
# Для замены нулевых значений в столбце floors_total будем использовать средние значения floors_total в разрезе населенного пункта (locality_name).

# %%
df['floors_total'] = df['floors_total'].fillna(df.groupby('locality_name')['floors_total'].transform('mean'))

# %%
df['floors_total'].isna().sum()
# Out:
# 1

# %% [markdown]
# Оставшееся значение заменим средним значением  в столбце floors_total

# %%
df['floors_total'] = df['floors_total'].fillna(df['floors_total'].mean())

# %%
df['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Замена пропусков в столбце ceiling_height**

# %% [markdown]
# Для замены нулевых значений в столбце ceiling_height будем использовать средние значения ceiling_height в разрезе населенного пункта (locality_name).

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df.groupby('locality_name')['ceiling_height'].transform('mean'))

# %%
df['ceiling_height'].isna().sum()
# Out:
# 156

# %% [markdown]
# Оставшееся значение заменим средним значением  в разрезе кол-ва этажей в доме

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df.groupby('floors_total')['ceiling_height'].transform('mean'))

# %%
df['ceiling_height'].isna().sum()
# Out:
# 1

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].mean())

# %%
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:**
#
# Пропуски в данных образовались в результате заполнения не всех полей при публикации объявлений.
#
# В необходимых столбцах пропуски заполнены согласно выбранных стратегий
#
# В столбце city_сenters_nearest - пропуски заменить не удалось. 22,7% данных не будут учавствовать в аналитике по данному столбцу. Необходим запрос разработчикам, предоставимшим данные.

# %% [markdown]
# <a id ="change"></a>
# ### Приведение данные к нужным типам:

# %% [markdown]
# Приведение типа данных в столбце
#
# - first_day_exposition  к формату datetime
# - is_apartment к формату bool
# - floors_total, balcony к формату int64
#
# Значения в столбцах ponds_around_3000, parks_around_3000, days_exposition - остаются в формате float64, тк содержат значения NaN (float64)

# %%
df = df.astype({ 'is_apartment': "bool", 'floors_total': 'int64', 'balcony': 'int64'})

# %%
#df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
#df[['floors_total', 'balcony']] = df[['floors_total', 'balcony']].astype('int64')

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23699 non-null int64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18305 non-null float64
# city_сenters_nearest    18305 non-null float64
# parks_around_3000       18181 non-null float64
# ...

# %% [markdown]
# **Вывод:**
#
# Значения в столбцах приведены к соответствующим типам данных
#
# Значения в столбцах ponds_around_3000, parks_around_3000, days_exposition - остаются в формате float64, тк содержат значения NaN (float64)

# %% [markdown]
# ```python
#
# columns = [col1, col2, col3]
#
# for i in columns:
#     df[i] = df[i].fillna(0)
#
# ```

# %% [markdown]
# <a id ="calculation"></a>
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим в таблицу столбцы с следующими данными:
#
# - цена квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# **Расчет цены квадратного метра**

# %%
df['one_area_price'] = df['last_price'] / df['total_area']

# %% [markdown]
# **Добавление столбца с информацией о дне недели, месяце и годе публикации объявления**

# %%
df['year'] = df['first_day_exposition'].dt.year

# %%
df['month'] = df['first_day_exposition'].dt.month

# %%
df['weekday'] = df['first_day_exposition'].dt.weekday

# %% [markdown]
# **Добавление столбца с информацией о этаже квартиры, сгрппированных по категориям  первый, последний, другой**

# %%
def floor_sort (row):
    floor = row['floor']
    floors_total= row['floors_total']

    if floor == 1:
        return 'первый'

    if floor == floors_total:
        return 'последний'

    return 'дугой'

# %%
df['floor_group'] = df.apply(floor_sort, axis=1)

# %% [markdown]
# **Добавление столбца с информацией о соотношение жилой и общей площади**

# %%
df['living_total'] = df['living_area'] / df['total_area']

# %% [markdown]
# **Добавление столбца с информацией о соотношение площади кухни и общей площади**

# %%
df['kitchen_total'] = df['kitchen_area'] / df['total_area']

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0        2.700000            16         51.0      8         False  ...
# 1        2.644470            11         18.6      1         False  ...
# 2        2.803709             5         34.3      4         False  ...
# 3        2.803709            14         80.2      9         False  ...
# 4        3.030000            14         32.0     13         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  one_area_price  year  \
# ...

# %% [markdown]
# **Вывод**<br>
# В датафрейм добавлены столбцы one_area_price, year, month, weekday, floor_group, living_total, kitchen_total с необходимой информацией.

# %% [markdown]
# <a id ="investigation"></a>
# ## Исследовательский анализ данных

# %% [markdown]
# **Необходимо провести следующие исследования:**
#
# 1. Изучение следующих параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.
#
# 2. Изучение время продажи квартиры. Построение гистограмы. Подсчет средней и медианы. Ответить на следующие вопросы: Сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#
# 3. Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.
#
# 4. Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.
#
# 5. Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.
#
# 6. Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.
#
# 7. Выделить сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# <a id ="investigation_41"></a>
# ### Изучение параметров: площадь, цена, число комнат, высота потолков

# %% [markdown]
# Информация по параметрам:

# %%
df[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe().T
# Out:
#                   count          mean           std      min        25%  \
# total_area      23699.0  6.034865e+01  3.565408e+01     12.0       40.0
# last_price      23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.0
# rooms           23699.0  2.070636e+00  1.078405e+00      0.0        1.0
# ceiling_height  23699.0  2.771859e+00  1.009357e+00      1.0        2.6
#
#                          50%           75%          max
# total_area      5.200000e+01  6.990000e+01        900.0
# last_price      4.650000e+06  6.800000e+06  763000000.0
# rooms           2.000000e+00  3.000000e+00         19.0
# ceiling_height  2.725271e+00  2.803709e+00        100.0

# %% [markdown]
# **Площадь (столбец total_area):**

# %%
df['total_area'].hist(bins=300, grid=True, figsize=(10,7))
plt.title('Распределение значений общей площади')
plt.show()

# %%
df.boxplot(column='total_area', figsize=(10,7))
plt.title('Распределение значений общей площади')
plt.figure(figsize=(10,7))
plt.show()

# %%
df.query('total_area >= 200')['last_price'].count()
# Out:
# 231

# %% [markdown]
# Из гистограммы и «ящика с усами» видно что, верхний ус в районе 130 м2. Для более детального анализа, построим гистограмму, исключив значения более 200 м2 (231 значения - около 1% от общего кол-ва)

# %%
df['total_area'].hist(bins=300)
plt.xlim(0, 200)
plt.title('Распределение значений общей площади до 200м2')
plt.show()

# %%
df.boxplot(column='total_area')
plt.ylim(0, 200)
plt.title('Распределение значений общей площади до 200м2')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 12м2
# - Максимальное значение: 900м2
# - Среднее значение: 60м2
# - Медианное значение: 52м2
# - 25% Квартиль: 40м2
# - 75% Квартиль: 70м2
#
# Максимальное число квартир имеют площадь 40-70 м2, квартиры с площадью более 125 м2 можно считать выбросами.

# %% [markdown]
# **Цена (столбец last_price):**

# %%
df['last_price'].hist(bins=5000)
plt.title('Распределение значений цены')
plt.show()

# %%
df.boxplot(column='last_price')
plt.title('Распределение значений цены')
plt.show()

# %%
df.query('last_price >= 20000000')['last_price'].count()
# Out:
# 723

# %% [markdown]
# Для более детального анализа, построим гистограмму без 723 значения last_price более 20 000 000. (около 3,5% от всех данных)

# %%
df['last_price'].hist(bins=100, range = (0, 20000000))
plt.title('Распределение значений цены до 20 млн')
plt.show()

# %%
df['last_price'].hist(bins=5000)
plt.title('Распределение значений цены до 20 млн')
plt.xlim(0, 20000000)
plt.show()

# %%
df.boxplot(column='last_price')
plt.ylim(0, 20000000)
plt.title('Распределение значений цены до 20 млн')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 12 190
# - Максимальное значение: 763 000 000
# - Среднее значение: 6 541 549
# - Медианное значение: 4 650 000
# - 25% Квартиль: 3 400 000
# - 75% Квартиль: 6 800 000
#
# Цены более 12 000 000  являются выбросами из общей массы

# %% [markdown]
# **Число комнат (столбец rooms):**

# %%
df['rooms'].hist(bins=20)
plt.title('Распределение значений числа комнат')
plt.show()

# %%
df.boxplot(column='rooms')
plt.title('Распределение значений числа комнат')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 0
# - Максимальное значение: 19
# - Среднее значение: 2
# - Медианное значение: 2
# - 25% Квартиль: 1
# - 75% Квартиль: 3
#
# В основном присутствуют 1, 2-х, 3-х комнатные квартиры, немного 4-х и 5-ти комнатные, больш 5 комнат, можно считать выбросами.

# %% [markdown]
# **Высота потолков (столбец rooms):**

# %%
df['ceiling_height'].hist(bins=300)
plt.show()

# %%
df.boxplot(column='ceiling_height')
plt.show()

# %%
df['ceiling_height'].hist(bins=30, range = (0, 7))

# %%
df.boxplot(column='ceiling_height')
plt.ylim(0, 7)
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 1 м
# - Максимальное значение: 100 м
# - Среднее значение: 2,77 m
# - Медианное значение: 2,65 m
# - 25% Квартиль: 2,52
# - 75% Квартиль: 2,8
#
# Максимальное колличество квартир имеют потолки 2,5 м.
#
# Минимальное и максимальное значение высоты потолков -  выбросы не соответствующие реальности, значения меньше 2,3 м и больше 3,2 м - можно считать выбросами.
#
# Значение ыв 100м - ошибочные данные

# %%
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']
for column in columns:
    fig = plt.figure()
    ax_1 = fig.add_subplot(1, 2, 1)
    df[column].hist(bins=30)
    ax_2 = fig.add_subplot(1, 2, 2)
    df.boxplot(column=column)
    ax_1.set_title(f'Распределение {column}')
    ax_2.set_title(f'Ящик с усами {column}')
    fig.set_figwidth(15)
    fig.set_figheight(8)
    plt.show

# %% [markdown]
# <a id ="investigation_42"></a>
# ### Изучение время продажи квартиры. Построение гистограммы. Подсчет средней и медианы. Ответить на следующие вопросы: Сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
df['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
df['days_exposition'].hist(bins=30)

# %%
df.boxplot(column='days_exposition')

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 1 д.
# - Максимальное значение: 1580 д.
# - Среднее значение: 180 д.
# - Медианное значение: 95д.
# - 25% Квартиль: 45 д.
# - 75% Квартиль: 232д.
#
# Обычно продажа занимает около 95 дней.
#
# Быстрее 45 дней - можно считать быстрая продажа,
# Дольше 232 дней - можно считать медленная продажа.

# %% [markdown]
# <a id ="investigation_43"></a>
# ### Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.

# %% [markdown]
# В столбце ceiling_height нйдено значение в 100 м - нереальное значение. Фактически все значения меньше 2 м и больше 7м - выбросы, заменим их на среднее значение

# %%
df.loc[df.query('ceiling_height < 2 or ceiling_height > 7').index, 'ceiling_height'] = 2.77

# %% [markdown]
# В столбце last_price - минимальное значение цены - 12190.0 не соответствует действительности, скорее всего указали цену в тыс. Изменим значение на 12190000. Также максимальная стоимость в 720 млн  и все цены более 200 млн вызывает сомнения. Однако на этапе анализа данных не будем заменять или исключать данные значения, т.к. они могу оказаться реальными данными.

# %%
df.loc[df.query('last_price < 12191').index, 'last_price'] = 12190000

# %% [markdown]
# Пересчитаем значение в столбце one_area_price

# %%
df['one_area_price'] = df['last_price'] / df['total_area']

# %% [markdown]
# **Вывод**
# В данных есть сомнительные значения, так стоимость более 200 млн, число комнат более 7 - выбивающиеся значения. Однако на этапе анализа данных не будем заменять или исключать данные значения, т.к. они могу оказаться реальными данными.

# %% [markdown]
# <a id ="investigation_44"></a>
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# **Зависимость цены от площади:**

# %% [markdown]
# Коэффициент корреляции:

# %%
df['last_price'].corr(df['total_area'])
# Out:
# 0.6537407142641285

# %% [markdown]
# Диаграмма рассеяния

# %%
df.plot(x='total_area', y='last_price', kind='scatter')

# %% [markdown]
# График зависимости среднего(медианного) значения цены от площади

# %%
df.pivot_table(index = 'total_area', values = 'last_price', aggfunc = ['mean', 'median'])['median'].plot()

# %% [markdown]
# **Вывод**
#
# Наблюдается положительная зависимость между общей площадью и ценой квартиры, коэфф. корреляции 0,65

# %% [markdown]
# **Зависимость от удаленности от центра:**

# %%
df['last_price'].corr(df['city_сenters_nearest'])
# Out:
# -0.20718684214567473

# %%
df.plot(x='city_сenters_nearest', y='last_price', kind='scatter')

# %%
df.pivot_table(index = 'city_сenters_nearest', values = 'last_price', aggfunc = ['mean', 'median'])['median'].plot()

# %% [markdown]
# **Вывод**
#
# Наблюдается отрицательная зависимость цены от удаленности от центра. Коэффициент корреляции - 0,2. При этом после 9 км наблюдается резкий скачек уровня цен вниз.
#
# Коэффициент корреляции мог быть более выраженным, если бы не отсутствие в датафрейме информация по удаленности более чем у 38% данных.

# %% [markdown]
# **Зависимость стоимости от числа комнат:**

# %%
df['last_price'].corr(df['rooms'])
# Out:
# 0.3633404525374843

# %%
df.plot(x='rooms', y='last_price', kind='scatter')

# %%
df.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean', 'median'])['median'].plot()

# %% [markdown]
# **Вывод**
#
# Наблюдается положительная зависимость цены от числа комнат. Коэффициент корреляции - 0,36.

# %% [markdown]
# **Зависимость цены от этажа на котором размещена квартира:**

# %%
df.pivot_table(index = 'floor_group', values = 'last_price', aggfunc = ['mean', 'median'])
# Out:
#                      mean     median
#                last_price last_price
# floor_group
# дугой        6.675699e+06  4850000.0
# первый       4.803560e+06  3900000.0
# последний    7.362930e+06  4300000.0

# %% [markdown]
# **Вывод**
#
# Средняя стоимость квартиры на 1-м  и последнем этажах ниже чем на других, на последнем - самая низкая.

# %% [markdown]
# **Зависимость от даты размещения объявления**

# %%
df[['last_price','year', 'month', 'weekday']].corr()
# Out:
#             last_price      year     month   weekday
# last_price    1.000000 -0.043015  0.002733  0.001535
# year         -0.043015  1.000000 -0.269642 -0.004799
# month         0.002733 -0.269642  1.000000  0.011496
# weekday       0.001535 -0.004799  0.011496  1.000000

# %%
pd.plotting.scatter_matrix(df[['last_price','year', 'month', 'weekday']])
plt.show()

# %% [markdown]
# **Вывод**
#
# Стоимость не зависит от даты размещения объявления.

# %% [markdown]
# <a id ="investigation_45"></a>
# ### Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %% [markdown]
# Создание среза 10 населенных пунктов с наибольшим числом объявлений:

# %%
locality_names = df.groupby('locality_name')['locality_name'].count().sort_values(ascending = False).head(10)

# %%
locality_names
# Out:
# locality_name
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %%
df_locality_names = df.query('locality_name in @locality_names.index')

# %%
df_locality_names['locality_name'].value_counts()
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# Средняя цена квадратного метра:

# %%
df_locality_names.pivot_table(index = 'locality_name', values = 'one_area_price', aggfunc = ['mean', 'median'])
# Out:
#                             mean         median
#                   one_area_price one_area_price
# locality_name
# Всеволожск          68654.473986   65789.473684
# Выборг              58141.909153   58158.319871
# Гатчина             68746.146763   67796.610169
# Колпино             75424.579098   74723.748474
# Пушкин             103125.819291  100000.000000
# Санкт-Петербург    114856.115405  104770.266315
# деревня Кудрово     92473.547576   91860.465116
# посёлок Мурино      85752.189195   85878.462169
# посёлок Парголово   90175.913458   91642.857143
# посёлок Шушары      78677.364217   76876.172608

# %% [markdown]
# **Вывод**
#
# За среднюю стоимость жилья принимаем медианное значение, так как с учетом выбросов медиана точнее описывает данный параметр.
#
# Наибольшая средняя стоимость жилья - в Санкт-Петербурге: 104 770
#
# Наименьшая средняя стоимость жилья - в Выборге: 58 158

# %%
(
    df_locality_names.pivot_table(index = 'locality_name', values = 'one_area_price', aggfunc = ['mean', 'median'])
    .plot(figsize = (10, 7), rot = 45, grid = True, title = 'Среднее и медианное значение стоимости квадратного метра')
)

# %% [markdown]
# <a id ="investigation_46"></a>
# ### Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %% [markdown]
# Выделить квартиры в Санкт-Петербурге

# %%
df_st_petersburg = df.loc[df.query('locality_name == "Санкт-Петербург"').index]

# %%
df_st_petersburg['locality_name'].value_counts()
# Out:
# Санкт-Петербург    15721
# Name: locality_name, dtype: int64

# %% [markdown]
# Создать столбец с расстоянием до центра в километрах: округлить до целых значений.

# %%
df_st_petersburg['city_сenters_nearest_round'] = (df_st_petersburg['city_сenters_nearest']/1000).round()

# %%
df_st_petersburg[['city_сenters_nearest', 'city_сenters_nearest_round']].head()
# Out:
#    city_сenters_nearest  city_сenters_nearest_round
# 0               16028.0                        16.0
# 2               13933.0                        14.0
# 3                6800.0                         7.0
# 4                8098.0                         8.0
# 7               11634.0                        12.0

# %% [markdown]
# Посчитайть среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра.

# %%
df_st_petersburg.groupby('city_сenters_nearest_round')['last_price'].median().plot(kind = 'bar')

# %% [markdown]
# **Вывод**
#
# Центральная зона ограничивается 8 км., после этого средняя стоимость уменьшается

# %% [markdown]
# <a id ="investigation_47"></a>
# ### Выделить сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# Создадим срез данных объявлений о продаже квартир по Санкт-Петербургу, удаленных от центра не более чем на 8 км

# %%
df_st_petersburg_centre = df_st_petersburg.loc[df_st_petersburg.query('city_сenters_nearest_round < 8').index]

# %% [markdown]
# **Изучение параметров: площадь, цена, число комнат, высота потолков.**

# %% [markdown]
# **Площадь:**

# %%
df_st_petersburg_centre['total_area'].describe()
# Out:
# count    3525.000000
# mean       93.168641
# std        59.473561
# min        12.000000
# 25%        57.000000
# 50%        78.700000
# 75%       110.000000
# max       631.200000
# Name: total_area, dtype: float64

# %%
df_st_petersburg_centre['total_area'].hist(bins = 30)

# %%
df_st_petersburg_centre.boxplot(column='total_area')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 12 м2
# - Максимальное значение: 631 м2
# - Среднее значение: 93 м2
# - Медианное значение: 79м2
# - 25% Квартиль: 57 м2
# - 75% Квартиль: 110 м2
#
# В центре квартиры имеют большую среднюю площадь, чем во всем городе. Также имеет место значение в 631 м2 - выброс, который может быть как и оштбочным, так и реальным.

# %% [markdown]
# **Цена:**

# %%
df_st_petersburg_centre['last_price'].describe()
# Out:
# count    3.525000e+03
# mean     1.489553e+07
# std      2.432091e+07
# min      1.600000e+06
# 25%      6.690000e+06
# 50%      9.200000e+06
# 75%      1.450000e+07
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
df_st_petersburg_centre['last_price'].hist(bins = 300)

# %%
df_st_petersburg_centre.boxplot(column='last_price')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 16000000
# - Максимальное значение: 763 000 000
# - Среднее значение: 14180370
# - Медианное значение: 8960000
# - 25% Квартиль: 6450000
# - 75% Квартиль: 13900000
#
# В центре квартиры имеют большую среднюю стоимость, чем во всем городе. Также выбросы более 200 млн вызывают вопросы.

# %% [markdown]
# **Число комнат:**

# %%
df_st_petersburg_centre['rooms'].describe()
# Out:
# count    3525.000000
# mean        2.834326
# std         1.449808
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max        19.000000
# Name: rooms, dtype: float64

# %%
df_st_petersburg_centre['rooms'].hist(bins = 10)

# %%
df_st_petersburg_centre.boxplot(column='rooms')
plt.show()

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 0
# - Максимальное значение: 19
# - Среднее значение: 2
# - Медианное значение: 3
# - 25% Квартиль: 2
# - 75% Квартиль: 3
#
# Средние значения кол-ва комнат в центре соответствуют средним значениям по всему городу..

# %% [markdown]
# **Высота потолков**

# %%
df_st_petersburg_centre['ceiling_height'].describe()
# Out:
# count    3525.000000
# mean        2.992759
# std         0.336820
# min         2.400000
# 25%         2.803709
# 50%         2.803709
# 75%         3.150000
# max         6.000000
# Name: ceiling_height, dtype: float64

# %%
df_st_petersburg_centre['ceiling_height'].hist(bins = 30)

# %%
df_st_petersburg_centre.boxplot(column='ceiling_height')
plt.show()

# %% [markdown]
# Так как мы изменили значения в столбце ceiling_height на этапе 4.3 для сравнения, выведем данные в таблице df

# %%
df['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.742133
# std          0.230340
# min          2.000000
# 25%          2.600000
# 50%          2.725271
# 75%          2.803709
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# **Вывод:**
# - Минимальное значение: 2 м
# - Максимальное значение: 6 м
# - Среднее значение: 3 m
# - Медианное значение: 3 m
# - 25% Квартиль: 2,8
# - 75% Квартиль: 3,23
#
# Среднее значение высоты потолков в центре больше чем в городе на 0,3 м

# %% [markdown]
# **Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)**

# %%
df_st_petersburg_centre[['last_price', 'total_area', 'rooms', 'city_сenters_nearest_round', 'year', 'month', 'weekday']].corr()
# Out:
#                             last_price  total_area     rooms  \
# last_price                    1.000000    0.613480  0.314874
# total_area                    0.613480    1.000000  0.730397
# rooms                         0.314874    0.730397  1.000000
# city_сenters_nearest_round   -0.040549   -0.080937 -0.156661
# year                         -0.047101   -0.083269 -0.066291
# month                        -0.012761   -0.021820 -0.026147
# weekday                       0.028284    0.013249 -0.007036
#
#                             city_сenters_nearest_round      year     month  \
# last_price                                   -0.040549 -0.047101 -0.012761
# total_area                                   -0.080937 -0.083269 -0.021820
# rooms                                        -0.156661 -0.066291 -0.026147
# city_сenters_nearest_round                    1.000000  0.035943  0.000960
# year                                          0.035943  1.000000 -0.243528
# ...

# %%
df_st_petersburg.plot(x='total_area', y='last_price', kind='scatter')

# %%
df_st_petersburg.plot(x='rooms', y='last_price', kind='scatter')

# %%
df_st_petersburg.plot(x='city_сenters_nearest_round', y='last_price', kind='scatter')

# %%
df_st_petersburg.plot(x='year', y='last_price', kind='scatter')

# %%
df_st_petersburg.plot(x='month', y='last_price', kind='scatter')

# %%
df_st_petersburg.plot(x='weekday', y='last_price', kind='scatter')

# %%
df_st_petersburg.pivot_table(index = 'floor_group', values = 'last_price', aggfunc = ['mean', 'median'])
# Out:
#                      mean     median
#                last_price last_price
# floor_group
# дугой        7.953726e+06  5600000.0
# первый       6.176315e+06  4861000.0
# последний    1.035193e+07  5650000.0

# %% [markdown]
# **Вывод**
#
# Наибольшее влияние на цену оказывают следующие факторы:
# - Общая площадь - положительная зависимость, коэффиц. корреляции 0.66
# - Количество комнат - положительная зависимость, коэффиц. корреляции 0.37
# - удалённость от центра - отрицательная зависимость, коэффиц. корреляции -0,26
#
# Так же, как и во всем городе, влияние оказывает этаж на котором расположена квартира: первый и последний - дешевле чем другие, первый - самый дешевый

# %%
columns = ['total_area', 'rooms', 'city_сenters_nearest_round', 'year', 'month', 'weekday']
for column in columns:
    fig = plt.figure()
    ax_1 = fig.add_subplot(1, 2, 1)
    ax_1.scatter(x=df_st_petersburg[column], y=df_st_petersburg['last_price'])
    ax_2 = fig.add_subplot(1, 2, 2)
    ax_2.scatter(x=df_st_petersburg_centre[column], y=df_st_petersburg_centre['last_price'])
    ax_1.set_title(f'Весь город  {column}')
    ax_2.set_title(f'Центр {column}')
    fig.set_figwidth(15)
    fig.set_figheight(8)
    plt.show

# %%
df_st_petersburg_centre[['total_area', 'one_area_price', 'last_price', 'rooms', 'ceiling_height']].describe().T
# Out:
#                  count          mean           std           min  \
# total_area      3525.0  9.316864e+01  5.947356e+01  1.200000e+01
# one_area_price  3525.0  1.452280e+05  9.362386e+04  1.534527e+04
# last_price      3525.0  1.489553e+07  2.432091e+07  1.600000e+06
# rooms           3525.0  2.834326e+00  1.449808e+00  0.000000e+00
# ceiling_height  3525.0  2.992759e+00  3.368202e-01  2.400000e+00
#
#                          25%           50%           75%          max
# total_area      5.700000e+01  7.870000e+01  1.100000e+02        631.2
# one_area_price  1.000000e+05  1.236220e+05  1.558140e+05    1907500.0
# last_price      6.690000e+06  9.200000e+06  1.450000e+07  763000000.0
# rooms           2.000000e+00  3.000000e+00  3.000000e+00         19.0
# ceiling_height  2.803709e+00  2.803709e+00  3.150000e+00          6.0

# %%
df_st_petersburg[['total_area', 'one_area_price', 'last_price', 'rooms', 'ceiling_height']].describe().T
# Out:
#                   count          mean           std           min  \
# total_area      15721.0  6.475149e+01  4.041709e+01  1.200000e+01
# one_area_price  15721.0  1.148561e+05  5.257656e+04  1.534527e+04
# last_price      15721.0  8.063282e+06  1.301302e+07  1.190000e+06
# rooms           15721.0  2.171618e+00  1.148098e+00  0.000000e+00
# ceiling_height  15721.0  2.778341e+00  2.420506e-01  2.000000e+00
#
#                          25%           50%           75%          max
# total_area      4.200000e+01  5.500000e+01  7.460000e+01        900.0
# one_area_price  9.090909e+04  1.047703e+05  1.244389e+05    1907500.0
# last_price      4.200000e+06  5.500000e+06  8.170000e+06  763000000.0
# rooms           1.000000e+00  2.000000e+00  3.000000e+00         19.0
# ceiling_height  2.600000e+00  2.803709e+00  2.803709e+00          6.0

# %% [markdown]
# Из графиков видно, что факторы, влияющие на стоимость - одинаковые, как во всем городе, так и в центре.
#
# В центре - выше как средняя стоимость квадратного метра (на 200-300 тыс), так и средняя цена продажи квартиры и средняя площадь квартиры.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. В полученных данных в столбце city_сenters_nearest присутствует 23% которые невозможно заменить. Данный столбец спользуется для анализа при выполнении исследования. В реальном проекте необходимо было бы запрашивать разработчиков для уточнения данных. В учебном проекте - анализируем что есть.
# 2. При изучении параметров, обнаружены редкие и выбивающиеся значения. Логически объяснимые ошибки были исправлены, в остальных данных выбивающиеся значения были оставлены без изменения в целях анализа.
# 3. Обычно продажа занимает около 95 дней.
# - Быстрее 45 дней - можно считать быстрая продажа,
# - Дольше 232 дней - можно считать медленная продажа.
# 4. Наибольшее влияние на цену оказывают следующие факторы:
# - Общая площадь - положительная зависимость
# - Количество комнат - положительная зависимость
# - удалённость от центра - отрицательная зависимость
# - этаж на котором расположена квартира: первый и последний - дешевле чем другие, первый - самый дешевый
# 5. Наибольшая средняя стоимость жилья - в Санкт-Петербурге: 104 770 за 1м2, Наименьшая средняя стоимость жилья - в Выборге: 58 158 за 1м"
# 6. В Санкт-Петербурге выделен сегмент в радиусе 8 км от центра, как центральный. Проведен анализ:
# - Средняя стоимость жилья - выше чем во всем городе и округе
# - Среднее значение высоты потолков в центре больше чем в городе на 0,3 м
# - Среднее колличество комнат - сопоставимо с количеством комнат в городе.
# 7. Факторы, оказывающие влияние на цену в Центре, такие же как и во всем городе.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
